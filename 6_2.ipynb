# %% [markdown]
# # Assignment 6.2

# %% [markdown]
# This assignment is for visualization using matplotlib:<br>
# data to use:<br>
# url=
# https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_origina
# l.csv'<br>
# titanic = pd.read_csv(url)<br>
# Charts to plot:<br>
# 1. Create a pie chart presenting the male/female proportion<br>
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %% [markdown]
# <h2>Solution</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

def func(vals) :
    val = list(vals)
    return val

def pie_chart_vals(val):
    return str(round(val,2))+"%"

url='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic = pd.read_csv(url)
grouped_titanic = titanic.groupby('sex').agg(func)
female_number = len(grouped_titanic['pclass'].values[0])
male_number = len(grouped_titanic['pclass'].values[1])
vals = [male_number,female_number]
labels = ['Male','Female']
plt.pie(vals,labels=labels,colors=["red","blue"],autopct=pie_chart_vals,shadow=True)
plt.title("Male-Female Proportion")
plt.show()
x_female = grouped_titanic['fare'].values[0]
y_female = grouped_titanic['age'].values[0]
x_male = grouped_titanic['fare'].values[1]
y_male = grouped_titanic['age'].values[1]
plt.scatter(x_male,y_male,c="red",label="Male")
plt.scatter(x_female,y_female,c="blue",label="Female")
plt.legend()
plt.title("Fare vs. Age by Gender")
plt.xlabel("Fare")
plt.ylabel("Age")
plt.show()
